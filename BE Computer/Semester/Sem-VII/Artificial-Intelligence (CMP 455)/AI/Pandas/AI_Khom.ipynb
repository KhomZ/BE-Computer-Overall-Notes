# %%
import pandas 
studentData=pandas.read_csv("C:/Users/nepal/Downloads/student_results.csv")
studentDF=pandas.DataFrame(studentData)

# %%
# studentDF.iloc[4:7,2:5]
studentDF.set_index("Student ID", inplace=True)

# %%
studentDF
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
studentDF.iloc[3]
# Out:
# Class                     11
# Study hrs                  0
# Sleeping hrs              10
# Social Media usage hrs     1
# Mobile Games hrs           5
# Percantege                45
# Name: 1004, dtype: int64

# %%
#  studentDF[studentDF["Sleeping hrs"]==studentDF["Sleeping hrs"].max()]
studentDF[(studentDF["Mobile Games hrs"]==0 ) & (studentDF["Percantege"]>80)]
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1006           11         10             7                       0
# 1008           12         10             6                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1006                       0          96
# 1008                       0          90
# 1010                       0          85

# %%
studentDF[studentDF["Percantege"]>60]
# Out:
#             Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# Student ID
# 1002           10          6             8                       2
# 1005           11          4             7                       2
# 1006           11         10             7                       0
# 1007           12          4             6                       0
# 1008           12         10             6                       2
# 1010           12          6             9                       1
#
#             Mobile Games hrs  Percantege
# Student ID
# 1002                       0          80
# 1005                       0          75
# 1006                       0          96
# 1007                       0          80
# 1008                       0          90
# 1010                       0          85

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nepal'
